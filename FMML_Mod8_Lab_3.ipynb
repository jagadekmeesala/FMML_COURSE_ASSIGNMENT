# %% [markdown]
# <a href="https://colab.research.google.com/github/jagadekmeesala/FMML_COURSE_ASSIGNMENT/blob/main/FMML_Mod8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-14 07:30:29--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   215MB/s    in 0.3s
#
# 2023-05-14 07:30:30 (215 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 11432  1602.01132v3  We consider interactive algorithms in the pool...  stat
# 10769   1402.3070v1  We present a comprehensive study on the use of...    cs
# 22957  1711.08536v1  Modern machine learning systems such as image ...  stat
# 5675   1604.07356v1  We present a new paradigm for speeding up rand...  stat
# 21352  1801.03138v1  Experience replay allows a reinforcement learn...    cs
# ...             ...                                                ...   ...
# 15017   0808.3616v3  Meroitic is the still undeciphered language of...    cs
# 20329  1509.06731v1  Poker is a family of card games that includes ...    cs
# 11064   1312.7006v2  We consider the mixed regression problem with ...  stat
# 9399   1701.04895v1  For a social networking service to acquire and...    cs
# 11349  1510.07169v1  Frank-Wolfe (FW) algorithms have been often pr...  stat
#
#                                                    title  year  \
# 11432        Interactive algorithms: from pool to stream  2016
# 10769  Squeezing bottlenecks: exploring the limits of...  2014
# 22957  No Classification without Representation: Asse...  2017
# 5675   Fast nonlinear embeddings via structured matrices  2016
# 21352                      Deep In-GPU Experience Replay  2018
# ...                                                  ...   ...
# 15017  Constructing word similarities in Meroitic as ...  2008
# 20329  Poker-CNN: A Pattern Learning Strategy for Mak...  2015
# 11064  A Convex Formulation for Mixed Regression with...  2013
# 9399   Unknowable Manipulators: Social Network Curato...  2017
# 11349  Fast and Scalable Lasso via Stochastic Frank-W...  2015
#
#                                                 keywords
# 11432  [interactive, algorithms, interactive, algorit...
# 10769  [comprehensive, autoencoders, modelling, atten...
# 22957  [classifiers, available, examining, diversity,...
# 5675   [randomized, computations, frequently, functio...
# 21352  [experience, reinforcement, experiences, exper...
# ...                                                  ...
# 15017  [undeciphered, civilization, techniques, decip...
# 20329  [variations, hypothesize, representation, iter...
# 11064  [regression, components, adversarial, stochast...
# 9399   [networking, accurately, preferences, availabl...
# 11349  [algorithms, efficient, optimization, projecti...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 11432    [interactive, algorithms, interactive, algorit...
# 10769    [comprehensive, autoencoders, modelling, atten...
# 22957    [classifiers, available, examining, diversity,...
# 5675     [randomized, computations, frequently, functio...
# 21352    [experience, reinforcement, experiences, exper...
#                                ...
# 22338    [knowledge, statistical, unsupervised, unsuper...
# 24       [remarkably, successful, perceptual, vulnerabl...
# 22633    [comprehensive, optimization, optimization, ad...
# 10031    [reinforcement, autonomous, repertoires, behav...
# 26979    [quantitative, measurement, functional, anatom...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8888 words.
# Out of those 4609 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="c9ffc01d-55f7-47c8-a32e-610264d6cd70" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c9ffc01d-55f7-47c8-a32e-610264d6cd70")) {                    Plotly.newPlot(                        "c9ffc01d-55f7-47c8-a32e-610264d6cd70",                        [{"x":["interactively","suggested","distribution","interactive","generated","emulating","independently","immediately","responses","algorithms","observing","algorithm","classification","modelling","attention","exploring","bottleneck","reconstruction","bottlenecks","capabilities","autoencoder","automatic","squeezing","assessing","following","different","autoencoders","information","suitability","constructing","comprehensive","representation","structural","dimensionality","representations","examining","diversity","distributions","classifiers","available","developing","differences","emphasize","observable","performance","presented","computations","reduction","functions","significant","combinatorial","framework","transform","nonlinear","embeddings","properties","algorithmic","frequently","concentration","lindenstrauss","byproduct","correlations","improving","approaches","multivariate","complexity","particular","randomized","structured","environment","implementation","reinforcement","outputting","controller","experiences","experience","instances","techniques","predicted","including","proximity","estimates","threshold","alternatives","experimental","distillation","uncertainty","additional","lightweight","architectures","emphasizing","stochastic","iterations","extensive","normalization","probability","reconstruct","arbitrary","amplification","observation","respectively","reconstructed","considered","estimator","eigenmaps","dimensional","estimated","neighborhood","reconstructing","propagation","increases","diffusion","inpainting","hierarchical","plausible","separately","technique","interpolation","automatically","structure","challenge","advantage","introduce","demonstrate","recognition","disparate","situations","universal","effectively","effectiveness","spontaneous","objective","eliminate","predefined","detection","situation","supervised","formulate","traditional","accurately","identifying","thresholding","unrealistic","justifies","parameter","unobserved","theoretical","assumption","asynchronous","significantly","considers","applicability","efficiency","empirical","identification","quantization","selectivity","classifier","operations","inference","efficiently","databases","unsupervised","magnitude","projection","performances","clustering","experiments","furthermore","extractors","principle","convolution","generates","efficient","categorization","estimation","categories","potential","ambiguous","recognizes","conceptual","structurally","incorporates","facilitating","separates","collection","strategies","mechanical","literature","conversational","architecture","prototyping","development","reproduction","processing","conversation","minimizing","assignment","elaborate","perplexing"],"y":[2,26,234,48,184,2,36,5,26,590,13,839,565,53,155,44,14,107,4,36,30,183,2,23,87,777,21,708,8,37,72,364,74,58,251,11,48,113,129,274,56,64,13,19,882,163,20,96,244,236,55,528,67,65,67,212,51,22,8,1,1,23,104,457,20,221,288,19,101,129,135,125,3,22,11,29,101,394,52,278,15,72,29,28,368,4,93,127,18,116,4,146,25,149,24,179,29,86,2,73,93,14,138,22,1,198,56,31,17,75,54,25,5,91,25,35,245,20,163,350,136,104,318,548,374,3,67,40,128,226,12,171,12,22,342,33,209,54,183,69,83,12,3,4,137,5,159,63,13,269,26,38,152,154,112,27,5,161,77,216,144,76,163,71,56,36,155,627,187,13,45,53,55,380,15,209,79,157,15,4,28,6,40,9,9,70,89,12,120,11,253,5,122,4,288,17,54,30,8,2],"type":"bar"},{"x":["interactively","suggested","distribution","interactive","gener ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4609,), (4609, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8008333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Online</span> <span style=''>and</span> <span style=''>Adaptive</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Pseudoinverse</span> <span style='background-color:rgba(0, 255, 0, 0.31983805668016185);'>Solutions</span> <span style=''>for</span> <span style=''>ELM</span> <span style=''>Weights</span> <br/><br/><span style=''>The</span> <span style=''>ELM</span> <span style=''>method</span> <span style=''>has</span> <span style=''>become</span> <span style=''>widely</span> <span style=''>used</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.5789473684210527);'>regressions</span> <span style=''>problems</span> <span style=''>as</span> <span style=''>a</span> <span style=''>result</span> <span style=''>of</span> <span style=''>its</span> <span style=''>accuracy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simplicity</span> <span style=''>and</span> <span style=''>ease</span> <span style=''>of</span> <span style=''>use</span> <span style=''>The</span> <span style=''>solution</span> <span style=''>of</span> <span style=''>the</span> <span style=''>hidden</span> <span style=''>layer</span> <span style=''>weights</span> <span style=''>by</span> <span style=''>means</span> <span style=''>of</span> <span style=''>a</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>pseudoinverse</span> <span style='background-color:rgba(0, 255, 0, 0.49999999999999994);'>operation</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.31843575418994413);'>significant</span> <span style=''>contributor</span> <span style=''>to</span> <span style=''>the</span> <span style=''>utility</span> <span style=''>of</span> <span style=''>the</span> <span style=''>method</span> <span style=''>however</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conventional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>calculation</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>pseudoinverse</span> <span style=''>by</span> <span style=''>means</span> <span style=''>of</span> <span style=''>a</span> <span style=''>singular</span> <span style=''>value</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decomposition</span> <span style=''>(SVD)</span> <span style=''>is</span> <span style=''>not</span> <span style=''>always</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practical</span> <span style=''>for</span> <span style=''>large</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>or</span> <span style=''>for</span> <span style=''>online</span> <span style=''>updates</span> <span style=''>to</span> <span style=''>the</span> <span style=''>solution</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>discuss</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>incremental</span> <span style=''>methods</span> <span style=''>for</span> <span style=''>solving</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>pseudoinverse</span> <span style=''>which</span> <span style=''>are</span> <span style=''>suitable</span> <span style=''>for</span> <span style=''>ELM</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>careful</span> <span style=''>choice</span> <span style=''>of</span> <span style=''>methods</span> <span style=''>allows</span> <span style=''>us</span> <span style=''>to</span> <span style=''>optimize</span> <span style=''>for</span> <span style=''>accuracy</span> <span style=''>ease</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computation</span> <span style=''>or</ ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonparametric</span> <span style=''>Method</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Imputation</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Forecasting</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Multivariate</span> <span style=''>Time</span> <span style=''>Series</span> <br/><br/><span style=''>This</span> <span style=''>article</span> <span style=''>proposes</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>forecasting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>imputation</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>in</span> <span style=''>sparsely</span> <span style=''>observed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multivariate</span> <span style=''>time</span> <span style=''>series</span> <span style=''>The</span> <span style=''>method</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>appropriate</span> <span style=''>for</span> <span style=''>jointly</span> <span style=''>modeling</span> <span style=''>hundreds</span> <span style=''>of</span> <span style=''>time</span> <span style=''>series</span> <span style=''>with</span> <span style=''>widely</span> <span style=''>varying</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stationary</span> <span style=''>dynamics</span> <span style=''>Given</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collection</span> <span style=''>of</span> <span style=''>N</span> <span style=''>time</span> <span style=''>series</span> <span style=''>the</span> <span style=''>Bayesian</span> <span style=''>model</span> <span style=''>first</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>partitions</span> <span style=''>them</span> <span style=''>into</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independent</span> <span style=''>clusters</span> <span style=''>using</span> <span style=''>a</span> <span style=''>Chinese</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>restaurant</span> <span style=''>process</span> <span style=''>prior</span> <span style=''>Within</span> <span style=''>a</span> <span style=''>cluster</span> <span style=''>all</span> <span style=''>time</span> <span style=''>series</span> <span style=''>are</span> <span style=''>modeled</span> <span style=''>jointly</span> <span style=''>using</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>temporally</span> <span style=''>coupled</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extension</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Chinese</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>restaurant</span> <span style=''>process</span> <span style=''>mixture</span> <span style=''>Markov</span> <span style=''>chain</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>are</span> <span style=''>used</span> <span style=''>to</span> <span style=''>obtain</span> <span style=''>samples</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>which</span> <span style=''>are</span> <span style=''>then</span> <span style=''>used</span>  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimistic</span> <span style=''>Rates</span> <span style=''>for</span> <span style=''>Learning</span> <span style=''>with</span> <span style=''>a</span> <span style=''>Smooth</span> <span style=''>Loss</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>establish</span> <span style=''>an</span> <span style=''>excess</span> <span style=''>risk</span> <span style=''>bound</span> <span style=''>of</span> <span style=''>O(H</span> <span style=''>R</span> <span style=''>n2</span> <span style=''>R</span> <span style=''>n</span> <span style=''>sqrtH</span> <span style=''>L)</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirical</span> <span style=''>risk</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>with</span> <span style=''>an</span> <span style=''>H</span> <span style=''>smooth</span> <span style=''>loss</span> <span style=''>function</span> <span style=''>and</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypothesis</span> <span style=''>class</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.5789473684210527);'>Rademacher</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>R</span> <span style=''>n</span> <span style=''>where</span> <span style=''>L</span> <span style=''>is</span> <span style=''>the</span> <span style=''>best</span> <span style=''>risk</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>achievable</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypothesis</span> <span style=''>class</span> <span style=''>For</span> <span style=''>typical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypothesis</span> <span style=''>classes</span> <span style=''>where</span> <span style=''>R</span> <span style=''>n</span> <span style=''>sqrtRn</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>translates</span> <span style=''>to</span> <span style=''>a</span> <span style=''>learning</span> <span style=''>rate</span> <span style=''>of</span> <span style=''>O(RHn)</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>separable</span> <span style=''>(L0)</span> <span style=''>case</span> <span style=''>and</span> <span style=''>O(RHn</span> <span style=''>sqrtL</span> <span style=''>RHn)</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generally</span> <span style=''>We</span> <span style=''>also</span> <span style=''>provide</span> <span style=''>similar</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guarantees</span> <span style=''>for</span> <span style=''>online</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3113207547169811);'>stochastic</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>with</span> <span style=''>a</span> <span style=''>smooth</span> <span style=''>non</span> <span style=''>negative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>DeepProbe</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Information</span> <span style=''>Directed</span> <span style=''>Sequence</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Understanding</span> <span style=''>and</span> <span style=''>Chatbot</span> <span style=''>Design</span> <span style=''>via</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Recurrent</span> <span style=''>Neural</span> <span style=''>Networks</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Information</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extraction</span> <span style=''>and</span> <span style=''>user</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intention</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identification</span> <span style=''>are</span> <span style=''>central</span> <span style=''>topics</span> <span style=''>in</span> <span style=''>modern</span> <span style=''>query</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understanding</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recommendation</span> <span style=''>systems</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>DeepProbe</span> <span style=''>a</span> <span style=''>generic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>directed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interaction</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>which</span> <span style=''>is</span> <span style=''>built</span> <span style=''>around</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attention</span> <span style=''>based</span> <span style=''>sequence</span> <span style=''>to</span> <span style=''>sequence</span> <span style=''>(seq2seq)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recurrent</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>DeepProbe</span> <span style=''>can</span> <span style=''>rephrase</span> <span style=''>evaluate</span> <span style=''>and</span> <span style=''>even</span> <span style=''>actively</span> <span style=''>ask</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>questions</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>leveraging</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style=''>ability</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>made</span> <span style=''>possible</span> <span style=''>by</span> <span style=''>seq2seq</span> <span style=''>models</span> <span style=''>DeepProbe</span> <span style=''>makes</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decisions</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>derived</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style=''>(entropy)</span> <span style=''>measure</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditioned</span> <span style=''>on</span> <span style=''>user</span> <span style=''>inputs</span> <span style=''>possibly</span> <span style=''>with</span> <span style=''>multiple</span> <span style=''>rounds</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interactions</span> <span style=''>Three</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>namely</span> <span style=''>a</span> <span style=''>rewritter</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relevance</span> <span style=''>scorer ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.12962962962962962)
# 	processing (0.10256410256410256)
# 	knowledge (0.12535612535612536)
# 	segmentation (0.07193732193732194)
# 	architecture (0.0900997150997151)
# 	information (0.25213675213675213)
# 	detection (0.12179487179487179)
# 	convolutional (0.13568376068376067)
# 	different (0.2767094017094017)
# 	recognition (0.13319088319088318)
#
# Some Statistics words are:
# 	variables (0.1280120481927711)
# 	stochastic (0.1395582329317269)
# 	theoretical (0.14708835341365462)
# 	distribution (0.18122489959839358)
# 	statistical (0.1576305220883534)
# 	estimation (0.17620481927710843)
# 	algorithm (0.4086345381526104)
# 	dimensional (0.1857429718875502)
# 	inference (0.2073293172690763)
# 	regression (0.1922690763052209)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="8e7eb555-ca98-4d39-aea9-3ec7b80da61c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8e7eb555-ca98-4d39-aea9-3ec7b80da61c")) {                    Plotly.newPlot(                        "8e7eb555-ca98-4d39-aea9-3ec7b80da61c",                        [{"x":["interactively","suggested","distribution","interactive","generated","emulating","independently","immediately","responses","algorithms","observing","algorithm","classification","modelling","attention","exploring","bottleneck","reconstruction","bottlenecks","capabilities","autoencoder","automatic","squeezing","assessing","following","different","autoencoders","information","suitability","constructing","comprehensive","representation","structural","dimensionality","representations","examining","diversity","distributions","classifiers","available","developing","differences","emphasize","observable","performance","presented","computations","reduction","functions","significant","combinatorial","framework","transform","nonlinear","embeddings","properties","algorithmic","frequently","concentration","lindenstrauss","byproduct","correlations","improving","approaches","multivariate","complexity","particular","randomized","structured","environment","implementation","reinforcement","outputting","controller","experiences","experience","instances","techniques","predicted","including","proximity","estimates","threshold","alternatives","experimental","distillation","uncertainty","additional","lightweight","architectures","emphasizing","stochastic","iterations","extensive","normalization","probability","reconstruct","arbitrary","amplification","observation","respectively","reconstructed","considered","estimator","eigenmaps","dimensional","estimated","neighborhood","reconstructing","propagation","increases","diffusion","inpainting","hierarchical","plausible","separately","technique","interpolation","automatically","structure","challenge","advantage","introduce","demonstrate","recognition","disparate","situations","universal","effectively","effectiveness","spontaneous","objective","eliminate","predefined","detection","situation","supervised","formulate","traditional","accurately","identifying","thresholding","unrealistic","justifies","parameter","unobserved","theoretical","assumption","asynchronous","significantly","considers","applicability","efficiency","empirical","identification","quantization","selectivity","classifier","operations","inference","efficiently","databases","unsupervised","magnitude","projection","performances","clustering","experiments","furthermore","extractors","principle","convolution","generates","efficient","categorization","estimation","categories","potential","ambiguous","recognizes","conceptual","structurally","incorporates","facilitating","separates","collection","strategies","mechanical","literature","conversational","architecture","prototyping","development","reproduction","processing","conversation","minimizing","assignment","elaborate","perplexing","constraints","discriminative","essentially","heuristic","sequences","generally","association","challenging","ambiguities","appearances","integrated","distinguish","directions","discourse","processes","conditional","contextual","researchers","interactions","characterise","conversations","individual","sequential","associated","consistent","classifying","increasing","accompanied","outperform","supporting","improvements","correction","statistical","anomalies","application","fundamental","disaggregation","convolutional","consistently","precipitation","longstanding","computation","availability","determine","incremental","computing","intermediate","decomposable","difference","influence","evaluating","solutions","relevance","demonstr ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	disaggregation
# 	confounders
# 	decomposability
# 	suboptimality
# 	sridharan
# 	approachability
# 	conjugacy
# 	concordance
# 	schizophrenia
# 	disentanglement
# 	penalizations
# 	debiasing
# 	thetastar
# 	agglomeration
# 	profitable
# 	monetization
# 	quadratically
# 	acceptancerejection
# 	adversarially
# 	methylation
# Some words which never appear in Statistics papers:
# 	squeezing
# 	outputting
# 	experiences
# 	ambiguous
# 	recognizes
# 	conversational
# 	reproduction
# 	perplexing
# 	discourse
# 	conversations
# 	understandability
# 	rectification
# 	formations
# 	stabilization
# 	overwhelm
# 	commonsense
# 	participated
# 	monolingual
# 	edinburgh
# 	experimented

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.059133041695984e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7558333333333334
